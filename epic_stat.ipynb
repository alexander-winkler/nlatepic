# %%
import csv

# %%
with open('works.csv', 'r') as CSV:
    csvreader = csv.reader(CSV)
    next(csvreader)
    for row in csvreader:
        print(row)
    print(entries)
# Out:
# ['Petrus Apollonius @Collatius', 'Q61474878', '', '', '', '', '', '', '', '', '', '', 'Hierosolyma', '4', '2565', 'hex', '', '', '', '', '', '', '', 'hist_far', '', '', 'braunPedisequaCamenaeZur2020: 23', '', '', '', '', '', 'http://mdz-nbn-resolving.de/urn:nbn:de:bvb:12-bsb10207574-7 ', '', '', '', '', '', '', '', '', '', '', '']
# ['Jacopo @Sadoleto', 'Q682478', '', '', '', '', '', '', '', '', '', '', 'Curtius', '1', '350', 'hex', '', '', '', '', '', '', '', 'hist_far', '', '', 'braunPedisequaCamenaeZur2020: 29', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['Hieronymus @Maripertus', 'Q26265364', '', '', '', '', '', '', '', '', '', '', 'Seraphicae', '20', '5300', 'hex', '', '', '', '', '', '', '', 'hag', '', '', 'braunPedisequaCamenaeZur2020: 34', '', '', '46673', '', 'urn:nbn:de:bvb:12-bsb10190898-5 ', 'http://mdz-nbn-resolving.de/urn:nbn:de:bvb:12-bsb10190898-5 ', '', '', '', '', '', '', '', '', '', '', '']
# ...

# %%
dir(csvreader)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_fieldnames',
#  'dialect',
#  'fieldnames',
#  'line_num',
#  'reader',
#  'restkey',
#  'restval']

# %%
csvreader.fieldnames
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-ef69ac421c86> in <module>
# ----> 1 csvreader.fieldnames
#
# /usr/lib/python3.6/csv.py in fieldnames(self)
#      96         if self._fieldnames is None:
#      97             try:
# ---> 98                 self._fieldnames = next(self.reader)
#      99             except StopIteration:
#     100                 pass
#
# ValueError: I/O operation on closed file.
